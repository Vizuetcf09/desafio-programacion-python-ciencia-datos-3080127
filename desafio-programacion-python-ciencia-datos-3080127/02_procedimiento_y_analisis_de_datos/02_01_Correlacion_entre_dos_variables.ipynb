# %% [markdown]
# # Procedimiento y analisis de datos

# %% [markdown]
# ## Correlaciṕon entre dos variables

# %% [markdown]
# ### Apuntes

# %% [markdown]
# #### Correlación
#
# Denota una asociación entre dos variables cuantitativas.
#
# #### Correlación positiva
#
# En la correlación positova, las variables se mueven en la misma dirección
#
# #### Correlación negativa
#
# Se lellama correlacióin positiva, cuando el valor de una variable aumenta, y el valor de la otra disminuye
#
# #### Correlación neutral o de valor cero
#
# En este tipo de variables, no existe una correlación, por lo tanto, el valor de una no afecta el valor de la otra, son independientes.
#
# #### Desafío
#
# averiguar si existe relación entre los años de experiencia y el salario, utilizando Python y la libreria de Pandas

# %% [markdown]
# ### Code | Correlaciṕon entre dos variable

# %%
#### Code | Correlaciṕon entre dos variable

# !pip install pandas seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: seaborn in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/vizuetcf/Escritorio/Vizuetcf09/Spetializations & Certifications/Linkedin Courses- Desafio de Programación - Python para ciencia de datos/desafio-programacion-python-ciencia-datos-3080127/env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd  
import seaborn as sns

# %% [markdown]
# ## Calculatr la media (promedio) para cada columna

# %% [markdown]
# ## Obtener mínimo, máximo,desviación estándar y varianza de un dataframe

# %% [markdown]
# ## Normalizar las columnas de un dataframe

# %% [markdown]
# ## Agregar un registroi a un dataframe

# %% [markdown]
# ## Extraer los nombres de las columnas que sean del tipo numérico

# %% [markdown]
# ## Extraer las filas que cumplen con un criterio

# %% [markdown]
# ## Extraer lo registros mas altos

# %% [markdown]
# ## Cambiar el orden de las columnas en un dataframe
